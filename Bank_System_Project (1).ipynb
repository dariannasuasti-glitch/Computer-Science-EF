# %% [markdown]
# #Simple banking System

# %%
#create an simple banking system
#declare variables to check the log in of the user
user="Darianna2006"
passwordsaved=172941
#determine the attempts a empty value could help us to pu conditions if the number increase or decreasee
attempts = 0
balance=1000.00

#Create login system
# create a condition with the empty variable
while attempts <= 3:
  #ask for a input and determine the type of input just to clasify data
  user_name=str(input("Enter your username: "))
  password= int(input("Enter your password: "))

#if inside the loop while
# to repeat until the condition be reach
  if user_name == user and password == passwordsaved:
    print('Successfully logged in')
# break to stop asking the password and username if the condition is true
    break
#Create a condition to sum the attemts to the empty variable this serve to callae the empty
  else:
    attempts += 1
    print('Wrong details')

#create a condition for ==3 or more

if attempts >3:
  print('Access denied. Contact bank')

#print the menu
else:
  while True:
    print('Main menu')
    print('1. Check balance')
    print('2. Deposite money')
    print('3. Withdrawal money')
    print('4. Exit the system')
#create a varble where te user can decide the menu
    choice = input('Select option')
#check balance
    if choice == '1':
      print(balance)
# the option 2 in the menu
    elif choice =='2':
#ask user input for the deposit
      deposit = float(input('value for the deposit'))
      if deposit >0:
#add the deposit to the balance with the add and pu the result in the deposit
        balance += deposit
        print('your new balance', balance)
      else:
        print('try again')
#Create system for withdraw money
    elif choice == '3':
      withdrawal = float(input("Value for the withdrawal:"))
      #Create a condition to check if withdrawal is possible
      if withdrawal <= balance:
        balance -= withdrawal
        print("transaction accepted", balance)
      else:
        ("insufficient funds", balance)
# the next choice in the menu == serve if the input math with this condition
    elif choice =='4':
      print('exit the bank account, I hope to see you soon')
      break
# Out:
# enter your username: Dariana2006
# enter your password: 172941
# Wrong details
# enter your username: Darianna2006
# enter your password: 172941
# Successfully logged in
# Main menu
# 1. Check balance
# 2. Deposite money
# 3. Withdrawal money
# 4. Exit the system
# Select option1
# 1000.0
# Main menu
# 1. Check balance
# 2. Deposite money
# 3. Withdrawal money
# 4. Exit the system
# Select option2
# value for the deposit100
# your new balance 1100.0
# Main menu
# 1. Check balance
# 2. Deposite money
# 3. Withdrawal money
# 4. Exit the system
# Select option3
# Value for the withdrawal:24
# transaction accepted 1076.0
# Main menu
# 1. Check balance
# 2. Deposite money
# 3. Withdrawal money
# 4. Exit the system
# Select option1
# 1076.0
# Main menu
# 1. Check balance
# 2. Deposite money
# 3. Withdrawal money
# 4. Exit the system
# Select option4
# exit the bank account, I hope to see you soon

# %%
attempts
# Out:
# 1
